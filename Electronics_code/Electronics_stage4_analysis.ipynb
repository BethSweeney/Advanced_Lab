# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Section 1 - Test PWM Duty Cycle & Frequency

# %% [markdown]
# ## Section 1.1 - Load in Data and sort

# %%
## Load in 25% duty cycle files

DC_25_1K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_25c_1k_1.csv")
DC_25_10K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_25c_10k_1.csv")
DC_25_100K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_25c_100k_1.csv")

# %%
## Load in 50% duty cycle files

DC_50_10K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_50db_10k__1.csv")
DC_50_10K_1 = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_50dc_10k__1.csv")

# %%
## Load in 75% duty cycle files

DC_75_1K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_75c_1k_1.csv")
DC_75_10K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_75c_10k_1.csv")
DC_75_100K = pd.read_csv(r"C:\Users\bethx\OneDrive\Documents\electronics_files\scope_75c_100k_1.csv")

# %%
## Convert 25s to np array to plot
DC_25_1K_sec = np.array(DC_25_1K['second'])
DC_25_1K_volt = np.array(DC_25_1K['Volt'])

DC_25_10K_sec = np.array(DC_25_10K['second'])
DC_25_10K_volt = np.array(DC_25_10K['Volt'])

DC_25_100K_sec = np.array(DC_25_100K['second'])
DC_25_100K_volt = np.array(DC_25_100K['Volt'])

# %%
## Convert 50s to np array to plot
DC_50_10K_sec = np.array(DC_50_10K['second'])
DC_50_10K_volt = np.array(DC_50_10K['Volt'])

DC_50_10K_sec_1 = np.array(DC_50_10K_1['second'])
DC_50_10K_volt_1 = np.array(DC_50_10K_1['Volt'])

# %%
## Convert 75s to np array to plot
DC_75_1K_sec = np.array(DC_75_1K['second'])
DC_75_1K_volt = np.array(DC_75_1K['Volt'])

DC_75_10K_sec = np.array(DC_75_10K['second'])
DC_75_10K_volt = np.array(DC_75_10K['Volt'])

DC_75_100K_sec = np.array(DC_75_100K['second'])
DC_75_100K_volt = np.array(DC_75_100K['Volt'])

# %% [markdown]
# ## Section 1.2 - Plot Data

# %% [markdown]
# ### 25% Duty Cycle

# %%
plt.plot(DC_25_1K_sec,DC_25_1K_volt)
plt.title('25% Duty Cycle, 1kHz')
# Out:
# Text(0.5, 1.0, '25% Duty Cycle, 1kHz')

# %%
plt.plot(DC_25_10K_sec,DC_25_10K_volt)
plt.title('25% Duty Cycle, 10kHz')
# Out:
# Text(0.5, 1.0, '25% Duty Cycle, 10kHz')

# %%
plt.plot(DC_25_100K_sec,DC_25_100K_volt)
plt.title('25% Duty Cycle, 100kHz')
# Out:
# Text(0.5, 1.0, '25% Duty Cycle, 100kHz')

# %% [markdown]
# ### 50% Duty Cycle

# %%
plt.plot(DC_50_10K_sec_1,DC_50_10K_volt_1)
plt.title('50% Duty Cycle, 10kHz')
# Out:
# Text(0.5, 1.0, '50% Duty Cycle, 10kHz')

# %% [markdown]
# ### 75% Duty Cycle

# %%
plt.plot(DC_75_1K_sec,DC_75_1K_volt)
plt.title('75% Duty Cycle, 1kHz')
# Out:
# Text(0.5, 1.0, '75% Duty Cycle, 1kHz')

# %%
plt.plot(DC_75_10K_sec,DC_75_10K_volt)
plt.title('75% Duty Cycle, 10kHz')
# Out:
# Text(0.5, 1.0, '75% Duty Cycle, 10kHz')

# %%
plt.plot(DC_75_100K_sec,DC_75_100K_volt)
plt.title('75% Duty Cycle, 100kHz')
# Out:
# Text(0.5, 1.0, '75% Duty Cycle, 100kHz')

# %% [markdown]
# # Section 2 - Simple DAC

# %% [markdown]
# ## Section 2.1 - Load in Data and sort

# %%
# set up file path shortcut 

DAC = r'C:\Users\bethx\OneDrive\Documents\electronics_files'

# %%
# Load in DAC data for Fc of 53 Hz (R=30k Ohms) - Several takes,, find best

DAC_Fc_53_1 = pd.read_csv(DAC+"\\scope_dac_fc_53_1.csv")
DAC_Fc_53_2 = pd.read_csv(DAC+"\\scope_dac_fc_53_2.csv")
DAC_Fc_53_3 = pd.read_csv(DAC+"\\scope_dac_fc_53_3_1.csv")
DAC_Fc_53_4 = pd.read_csv(DAC+"\\scope_dac_fc_53_3_2.csv")

# %%
# Load in DAC data for Fc of 570 ohms (R= 2.7k Ohms) - Several takes,, find best

DAC_Fc_570_1 = pd.read_csv(DAC+"\\scope_dac_fc_570_1_1.csv")
DAC_Fc_570_2 = pd.read_csv(DAC+"\\scope_dac_fc_570_1_2.csv")
DAC_Fc_570_3 = pd.read_csv(DAC+"\\scope_dac_fc_570_2_1.csv")
DAC_Fc_570_4 = pd.read_csv(DAC+"\\scope_dac_fc_570_2_2.csv")

# %%
# Load in DAC data for Fc of 5900 ohms (R= 270 Ohms) - Several takes,, find best

DAC_Fc_5900_1 = pd.read_csv(DAC+"\\scope_dac_fc_590__1.csv")
DAC_Fc_5900_2 = pd.read_csv(DAC+"\\scope_dac_fc_590__2.csv")
DAC_Fc_5900_3 = pd.read_csv(DAC+"\\scope_dac_fc_5900_1.csv")
DAC_Fc_5900_4 = pd.read_csv(DAC+"\\scope_dac_fc_5900_2.csv")

# %%
## Convert 53 Hz to np array to plot
DAC_Fc_53_1_sec = np.array(DAC_Fc_53_1['second'])
DAC_Fc_53_1_volt = np.array(DAC_Fc_53_1['Volt'])

DAC_Fc_53_2_sec = np.array(DAC_Fc_53_2['second'])
DAC_Fc_53_2_volt = np.array(DAC_Fc_53_2['Volt'])

DAC_Fc_53_3_sec = np.array(DAC_Fc_53_3['second'])
DAC_Fc_53_3_volt = np.array(DAC_Fc_53_3['Volt'])

DAC_Fc_53_4_sec = np.array(DAC_Fc_53_4['second'])
DAC_Fc_53_4_volt = np.array(DAC_Fc_53_4['Volt'])

# %%
## Convert 570 Hz to np array to plot
DAC_Fc_570_1_sec = np.array(DAC_Fc_570_1['second'])
DAC_Fc_570_1_volt = np.array(DAC_Fc_570_1['Volt'])

DAC_Fc_570_2_sec = np.array(DAC_Fc_570_2['second'])
DAC_Fc_570_2_volt = np.array(DAC_Fc_570_2['Volt'])

DAC_Fc_570_3_sec = np.array(DAC_Fc_570_3['second'])
DAC_Fc_570_3_volt = np.array(DAC_Fc_570_3['Volt'])

DAC_Fc_570_4_sec = np.array(DAC_Fc_570_4['second'])
DAC_Fc_570_4_volt = np.array(DAC_Fc_570_4['Volt'])

# %%
## Convert 5900 Hz to np array to plot
DAC_Fc_5900_1_sec = np.array(DAC_Fc_5900_1['second'])
DAC_Fc_5900_1_volt = np.array(DAC_Fc_5900_1['Volt'])

DAC_Fc_5900_2_sec = np.array(DAC_Fc_5900_2['second'])
DAC_Fc_5900_2_volt = np.array(DAC_Fc_5900_2['Volt'])

DAC_Fc_5900_3_sec = np.array(DAC_Fc_5900_3['second'])
DAC_Fc_5900_3_volt = np.array(DAC_Fc_5900_3['Volt'])

DAC_Fc_5900_4_sec = np.array(DAC_Fc_5900_4['second'])
DAC_Fc_5900_4_volt = np.array(DAC_Fc_5900_4['Volt'])

# %% [markdown]
# ## Section 2.2 - Plot Data

# %% [markdown]
# ### 53 Hz, 30kOhm

# %%
plt.plot(DAC_Fc_53_1_sec,DAC_Fc_53_1_volt)
plt.plot(DAC_Fc_53_2_sec,DAC_Fc_53_2_volt)

plt.title('30 kOhm, 53Hz')
# Out:
# Text(0.5, 1.0, '30 kOhm, 53Hz')

# %%
plt.plot(DAC_Fc_53_3_sec,DAC_Fc_53_3_volt)
plt.plot(DAC_Fc_53_4_sec,DAC_Fc_53_4_volt)

plt.title('30 kOhm, 53Hz')
# Out:
# Text(0.5, 1.0, '30 kOhm, 53Hz')

# %% [markdown]
# ### 570 Hz, 2.7 kOhm

# %%
plt.plot(DAC_Fc_570_1_sec,DAC_Fc_570_1_volt)
plt.plot(DAC_Fc_570_2_sec,DAC_Fc_570_2_volt)

plt.title('2.7 kOhm, 570Hz')
# Out:
# Text(0.5, 1.0, '2.7 kOhm, 570Hz')

# %%
plt.plot(DAC_Fc_570_3_sec,DAC_Fc_570_3_volt)
plt.plot(DAC_Fc_570_4_sec,DAC_Fc_570_4_volt)

plt.title('2.7 kOhm, 570Hz')
# Out:
# Text(0.5, 1.0, '2.7 kOhm, 570Hz')

# %% [markdown]
# ### 5900 Hz, 270 Ohm

# %%
plt.plot(DAC_Fc_5900_1_sec,DAC_Fc_5900_1_volt)
plt.plot(DAC_Fc_5900_2_sec,DAC_Fc_5900_2_volt)

plt.title('270 Ohm, 5900Hz')
# Out:
# Text(0.5, 1.0, '270 Ohm, 5900Hz')

# %%
plt.plot(DAC_Fc_5900_3_sec,DAC_Fc_5900_3_volt)
plt.plot(DAC_Fc_5900_4_sec,DAC_Fc_5900_4_volt)

plt.title('270 Ohm, 5900Hz')
# Out:
# Text(0.5, 1.0, '270 Ohm, 5900Hz')

# %% [markdown]
# # Section 3 - Analogue output functions

# %%
# Input vs Measured Frequencies - sine wave,, below Fc
Input_Frequency_below_Fc = [50,25,75,100,10,20]

Output_Frequency = [39.891,22.2,54.6,66.4,9.51,18.15]
Output_Frequency_w_correction = [49.51,24.81,73.59,97.01,9.97,19.91]

# %%
# Input vs Measured Frequencies - sine wave,, below Fc
all_input_frequencies = [50,25,75,100,10,20,500,1000,750,1500,2000,2500]

all_output_frequencies = [39.891,22.2,54.6,66.4,9.51,18.15,141.8,163.2,156.2,202.9,227.5,227.5]
all_output_frequencies_w_correction = [49.51,24.81,73.59,97.01,9.97,19.91,227.5,227.5,227.5,227.5,227.5,227.5]

# %%
plt.scatter(Input_Frequency_below_Fc,Output_Frequency)
plt.scatter(Input_Frequency_below_Fc,Output_Frequency_w_correction)

# %%
plt.scatter(all_input_frequencies,all_output_frequencies)
#plt.scatter(all_input_frequencies,all_output_frequencies_w_correction)
